# %%
# prompt(How much you make last year)
# 
# money value within a range return a number

# %%
from ipyturtle import Turtle
t = Turtle(fixed=False, width=320, height=320)

def circle():
        for i in range(360):
            t.forward(1)
            t.left(1)
            
def square():
    t.forward(60)
    t.left(90)
    t.forward(120)
    t.left(90)
    t.forward(120)
    t.left(90)
    t.forward(120)
    t.left(90)
    t.forward(60)
    
def triangle():
    t.left(30)
    t.forward(120)
    t.left(120)
    t.forward(120)
    t.left(121)
    t.forward(120)
    t.left(90)

def trapazoid():
    t.left(30)
    t.forward(60)
    t.left(60)
    t.forward(60)
    t.left(60)
    t.forward(60)
    t.left(121)
    t.forward(120)
    t.left(90)
    
t.pendown()
t

# %%
t.penup()
t.right(90)
t.forward(60)
t.left(90)
t.pendown()

print("Welcome to Tax Calculator")
print("   We make taxes fun!\n")
print("Before we begin lets pick a shape:")
print("(1) Circle, (2) Square, (3) Triangle, (4) Trapazoid")

shape = int(-1)
while shape >= 5 or shape < 0: 
    shape = int(input("What's your shape? "))
    if shape < 2:
        circle()
        print("That's super great, right?!")
    elif shape < 3:
        square()
        print("Pretty lit square you got there!")
    elif shape < 4:
        triangle()
        print("isocoles!")
    elif shape < 5:
        trapazoid()
        print("That's mathmatical!")

# %%
print("Next, we'll focus on taxes? \n((1)single, (2)married filing jointly, (3)married filing seperately, (4)Head of Household)")

#filing = int(1)
#monies = 16000

filing = int(input("How will you file? "))
monies = int(input("What is your gross monies? "))

if filing < 2:
    if monies < 9325:
        print("the ministry of not-so-magic will take 10% and a turkey sandwhich")
        print("this will be %d" % (monies * .10))
    if monies < 37950:
        print("the dominion will take 15% and an everything burrito")
        print("this will be %d" % (monies * .15))
    if monies < 91900:
        print("Big brother will take 25% and your lunch money")
        print("this will be %d" % (monies * .25))
    if monies < 191650:
        print("the powers-that-be will take 28% and a seat at your dinner table")
        print("this will be %d" % (monies * .28))
    if monies < 416700:
        print("them feds will take 33% and the first 5 of all your groceries")
        print("this will be %d" % (monies * .33))
    if monies < 418400:
        print("the bureaucracy will take 35% and your first born son")
        print("this will be %d" % (monies * .35))
    else:
        print("the governance will take 39.6% and your soul")
        print("this will be %d" % (monies * .396))

elif filing < 3:
    if monies < 18650:
        print("the ministry will take 10% and a turkey sandwhich")
        print("this will be %d" % (monies * .10))
    if monies < 75900:
        print("the dominion will take 15% and an everything burrito")
        print("this will be %d" % (monies * .15))
    if monies < 153100:
        print("Big brother will take 25% and your lunch money")
        print("this will be %d" % (monies * .25))
    if monies < 233350:
        print("the powers-that-be will take 28% and a seat at your dinner table")
        print("this will be %d" % (monies * .28))
    if monies < 416700:
        print("them feds will take 33% and the first 5 of all your groceries")
        print("this will be %d" % (monies * .33))
    if monies < 470700:
        print("the bureaucracy will take 35% and your first born son")
        print("this will be %d" % (monies * .35))
    else:
        print("the governance will take 39.6% and your soul")
        print("this will be %d" % (monies * .396))
        
elif filing < 4:
    if monies < 9325:
        print("the ministry will take 10% and a turkey sandwhich")
        print("this will be %d" % (monies * .10))
    if monies < 37950:
        print("the dominion will take 15% and an everything burrito")
        print("this will be %d" % (monies * .15))
    if monies < 76550:
        print("Big brother will take 25% and your lunch money")
        print("this will be %d" % (monies * .25))
    if monies < 116675:
        print("the powers-that-be will take 28% and a seat at your dinner table")
        print("this will be %d" % (monies * .28))
    if monies < 208350:
        print("them feds will take 33% and the first 5 of all your groceries")
        print("this will be %d" % (monies * .33))
    if monies < 235350:
        print("the bureaucracy will take 35% and your first born son")
        print("this will be %d" % (monies * .35))
    else:
        print("the governance will take 39.6% and your soul")
        print("this will be %d" % (monies * .396))
        
elif filing < 5:
    if monies < 13350:
        print("the ministry will take 10% and a turkey sandwhich")
        print("this will be %d" % (monies * .10))
    if monies < 50800:
        print("the dominion will take 15% and an everything burrito")
        print("this will be %d" % (monies * .15))
    if monies < 131200:
        print("Big brother will take 25% and your lunch money")
        print("this will be %d" % (monies * .25))
    if monies < 212500:
        print("the powers-that-be will take 28% and a seat at your dinner table")
        print("this will be %d" % (monies * .28))
    if monies < 416700:
        print("them feds will take 33% and the first 5 of all your groceries")
        print("this will be %d" % (monies * .33))
    if monies < 444550:
        print("the bureaucracy will take 35% and your first born son")
        print("this will be %d" % (monies * .35))
    else:
        print("the governance will take 39.6% and your soul")
        print("this will be %d" % (monies * .396))
