# %%
from ipyturtle import Turtle
t = Turtle(fixed=False, width=320, height=320)

def circle():
    for i in range(270):
        t.forward(1)
        t.left(1)
t.penup()
t.forward(35)
t.left(90)
t.forward(15)
t.right(45)
t.pendown()
t

# %%
circle()
t.penup()
t.right(45)
t.forward(40)
t.left(90)

# %%
t.pendown()
t.forward(90)
t.right(135)
t.forward(60)
t.left(90)
t.forward(60)
t.right(135)
t.forward(90)

# %%
t.penup()
t.right(135)
t.forward(150)
