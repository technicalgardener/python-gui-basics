# %%
# %%python
#
# from tkinter import *
# import time
#
# # make the tk window
# tk = Tk()
#
# # set a title
# tk.title("StarGame")
#
# # make the window resizable
# tk.resizable(0, 0)
#
# # put window on top
# tk.wm_attributes("-topmost", 1)
#
# # create a canvas
# canvas = Canvas(tk, width=900, height=600, bd=0, bg="darkcyan", highlightthickness=0)
#
# # put the canvas in window
# canvas.pack()
#
# # initialize our window
# tk.update()
#
# # ship class
# class Ship:
#     def __init__(self, canvas, image, x, y):
#         self.canvas = canvas
#         self.id = canvas.create_image(x, y, anchor=NW, image=image)
#     def fly_NE(self):
#         self.canvas.move(self.id, 1, -1)
#     def fly_SE(self):
#         self.canvas.move(self.id, 1, .1)
#     def fly_E(self):
#         self.canvas.move(self.id, 1, 0)
#     def firePhaser(self, x, y, angle):
#         print("Firing Phaser from %s, %s at angle %s" % (x, y, angle))
#         lineID = self.canvas.create_line(x, y, x+500, y+500, fill="purple",width=5)
#         return lineID
#
# def fireButton():
#     global phaserCount
#     phaser = 5
# btn = Button(tk, text="PewPew", command=fireButton)
# btn.pack()
#
#
# # falcon
# falcon_image = PhotoImage(file="assets/falcon.gif")
# Falcon = Ship(canvas, falcon_image, 200, 600)
#
# # enterprise
# enterprise_image = PhotoImage(file="assets/enterprise.gif")
# Enterprise = Ship(canvas, enterprise_image, -1000, 10)
#
# count = 0
# phaserCount = 0
# # main game loop
# while True:
#     #count += 1
#     #if count > 2000:
#     #   break
#
#     # fly Falcon NE
#     Falcon.fly_NE()
#
#     # fly Enterprise E
#     Enterprise.fly_SE()
#
#     # get enterprise position
#     pos = Enterprise.canvas.coords(Enterprise.id)
# #    if pos[0]%200 == 0:
# #        lineID = Enterprise.firePhaser(pos[0]+774, pos[1]+183, "SE")
# #        phaserCount = 25
# #    if phaserCount == 0:
#     try:
#         Enterprise.canvas.delete(lineID)
#     except:
#         pass
#     if phaserCount > 0:
#         lineID = Enterprise.firePhaser(pos[0]+774, pos[1]+183, "SE")
#         phaserCount -= 1
#
#
#
#     # get falcon position
#     pos = Falcon.canvas.coords(Falcon.id)
#     pos1 = Enterprise.canvas.coords(Enterprise.id)
#     # wrap falcon if off edge of canvas
#     if pos[0] > 900:
#         Falcon.canvas.move(Falcon.id, -750, 750)
#
#     if pos1[0] > 900:
#         Enterprise.canvas.move(Enterprise.id, -1900, -200)
#     #pos2 = Enterprise.canvas.coords(Enterprise.id)
#    # if pos[0] > 1000:
#     #    Enterprise.canvas.move(Enterprise.id, -1000, -750)
#
#     # tk refresh screen
#     tk.update_idletasks()
#     tk.update()
#
#     # set frame rate
#     time.sleep(0.015)
# Out:
# Traceback (most recent call last):
#   File "<stdin>", line 66, in <module>
#   File "<stdin>", line 32, in fly_NE
#   File "C:\Users\cmikk\Anaconda3\lib\tkinter\__init__.py", line 2585, in move
#     self.tk.call((self._w, 'move') + args)
# _tkinter.TclError: invalid command name ".!canvas"
